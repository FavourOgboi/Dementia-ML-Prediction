# %% [markdown]
# # Dementia Prediction Project
#
#  ![]( https://ch-api.healthhub.sg/api/public/content/44bcb8d6bd504474b0f3a5476ed3ec6a?v=698b258e&t=livehealthyheaderimage)
#
# The goal of this project is to analyze an existing dataset comparing individuals with and without dementia and to predict the likelihood of dementia in other individuals based off of this structured dataset

# %% [markdown]
# ## Alzheimer's
#
# A mental capacity decline severe enough to interfere with day-to-day functioning is referred to as dementia. One frequent instance is memory loss. Dementia is a group of symptoms associated with a decline in memory and other cognitive abilities that make daily tasks difficult. It is not a specific condition.
#
#
# ### Identification of Dementia
#
# One test is insufficient to diagnose dementia in an individual. Alzheimer's disease and other types of dementia are identified by doctors by:
#
# - A comprehensive assessment of medical history
# - A clinical assessment - Laboratory investigations
# - Seeing the distinct alterations in thought processes, day-to-day activities, and behavior that are indicative of each kind of dementia
#
# With great certainty, physicians can make the diagnosis of dementia. But pinpointing the exact kind of dementia can be hard because different dementias can have similar symptoms and neurological abnormalities. A physician may occasionally identify dementia without identifying the specific kind. In these situations, seeking advice from an expert like a geropsychologist or neurologist might be essential.

# %% [markdown]
# ### Algorithm Development Steps
#
# #### 1. Problem Definition
# Clearly defining the problem to solve. Understanding the objectives and the desired outcomes.
#
# #### 2. Data Collection
# Gathering all necessary data that will be used in the algorithm. Ensuring the data is relevant and sufficient for the task.
#
# #### 3. Data Preprocessing
# Preparing the data for analysis. This may include:
# - Cleaning the data (handling missing values, removing duplicates, etc.)
# - Encoding categorical variables
#
# #### 4. Exploratory Data Analysis (EDA)
# Performing exploratory data analysis to understand the data better. This includes:
# - Descriptive statistics (mean, median, mode, etc.)
# - Visualizations (histograms, scatter plots, box plots, etc.)
# - Identifying patterns and correlations
#
# #### 5 Normalizing or standardizing the data
#
# #### 6 Splitting the data into training and testing sets
#
# #### 7. Feature Engineering
#
# #### 8. Model Training

# %% [markdown]
# ## Understanding the Data
#
# ### Summary
# This dataset consists of a longitudinal study involving 150 subjects aged between 60 and 96. Each subject was scanned during two or more visits, with at least one year between each visit, resulting in a total of 373 imaging sessions. For each subject, 3 or 4 individual T1-weighted MRI scans obtained in single scan sessions are included. The subjects are all right-handed and include both men and women. Among them:
# - 72 subjects were classified as nondemented throughout the study.
# - 64 subjects were classified as demented at their initial visits and remained so for subsequent scans, including 51 individuals with mild to moderate Alzheimer’s disease.
# - 14 subjects were initially nondemented but were later classified as demented during subsequent visits.
#
# `Get the data`
# The dataset is from kaggle.com, get the csv file from the link below.
# [Dataset](https://www.kaggle.com/datasets/shashwatwork/dementia-prediction-dataset?resource=download)
#
# ### Variables and Their Meanings
# The dataset includes several key variables:
#
# - **Subject.ID**: Unique identifier for each subject.
# - **MRI.ID**: Unique identifier for each MRI session.
# - **Group**: Indicates the dementia status of the subject. It can be one of three categories:
#   - **Converted**: Subjects who were initially nondemented but later diagnosed as demented.
#   - **Demented**: Subjects diagnosed with dementia at the initial visit and remained so.
#   - **Nondemented**: Subjects who were not diagnosed with dementia throughout the study.
# - **Visit**: The number of the visit (e.g., first visit, second visit, etc.).
# - **MR.Delay**: The delay in days between the baseline visit and the MRI scan.
#
# ### Demographic Information
# - **M.F**: Gender of the subject (M for male, F for female).
# - **Hand**: Handedness of the subject (dropped since all subjects are right-handed).
# - **Age**: Age of the subject at the time of the scan.
# - **EDUC**: Years of education completed by the subject.
# - **SES**: Socioeconomic status of the subject as assessed by the Hollingshead Index of Social Position, categorized from 1 (highest status) to 5 (lowest status).
#
# ### Clinical Information
# - **MMSE**: Mini-Mental State Examination score, ranging from 0 (worst) to 30 (best). Used to assess cognitive impairment.
# - **CDR**: Clinical Dementia Rating, which scores the severity of dementia:
#   - 0 = No dementia
#   - 0.5 = Very mild dementia
#   - 1 = Mild dementia
#   - 2 = Moderate dementia
#
# ### Derived Anatomic Volumes
# - **eTIV**: Estimated total intracranial volume in cubic millimeters (mm³).
# - **nWBV**: Normalized whole-brain volume, expressed as a percentage of all voxels in the atlas-masked image that are labeled as gray or white matter by the automated tissue segmentation process.
# - **ASF**: Atlas scaling factor (unitless). It is the computed scaling factor that transforms native-space brain and skull to the atlas target, representing the determinant of the transform matrix.
#
# ### Mini–Mental State Examination (MMSE)
# The MMSE is a 30-point questionnaire widely used in clinical and research settings to measure cognitive impairment. It is used to screen for dementia, estimate the severity and progression of cognitive impairment, and monitor changes in an individual's cognitive function over time. It is not intended to provide a diagnosis on its own.
#
# ### MMSE Interpretations
# - A score of 24 or higher (out of 30) indicates normal cognition.
# - Scores below 24 indicate cognitive impairment, categorized as:
#   - Severe (≤9 points)
#   - Moderate (10–18 points)
#   - Mild (19–23 points)
#
# Scores may need adjustment based on educational attainment and age. A perfect score of 30 does not rule out dementia, while very low scores strongly correlate with dementia, though other mental disorders can also affect MMSE results. Physical issues, such as hearing or motor deficits, can also interfere with the test's interpretation.
#
# ### Clinical Dementia Rating (CDR)
# The CDR is a 5-point scale used to evaluate six domains of cognitive and functional performance, particularly in Alzheimer's disease and related dementias:
# - Memory
# - Orientation
# - Judgment & Problem Solving
# - Community Affairs
# - Home & Hobbies
# - Personal Care
#
# Ratings are derived from a semi-structured interview with the patient and a reliable informant, such as a family member. The CDR Scoring Table provides guidelines for making appropriate ratings. An overall CDR score, calculated using the CDR Scoring Algorithm, helps characterize and track the level of impairment:
# - 0 = Normal
# - 0.5 = Very Mild Dementia
# - 1 = Mild Dementia
# - 2 = Moderate Dementia
#
# ### Estimated Total Intracranial Volume (eTIV)
# The estimated total intracranial volume (eTIV) measures the cranial cavity's volume, outlined by the supratentorial dura matter or cerebral contour when dura is not clearly detectable. eTIV is used in studies involving cerebral structure analysis under different imaging modalities (e.g., MRI, DTI, SPECT, Ultrasound, CT). Due to its consistency during aging, eTIV is a reliable tool for correcting head size variations in morphological brain studies. It is reported as a covariate, along with age and gender, in regression analyses investigating neurodegenerative brain disorders like Alzheimer's disease. eTIV also helps evaluate age-related structural changes, atrophy patterns in mild cognitive impairment (MCI) and Alzheimer's disease (AD), and structural abnormalities in conditions such as schizophrenia and epilepsy.

# %% [markdown]
# ### **How to run the code**
#
# This notebook is an executable [Jupyter notebook](https://jupyter.org). You can _run_ this notebook and experiment with the code examples in a couple of ways: *using free online resources* (recommended) or *on your computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing the code is to **Run on Binder**. You can also "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
#
#
# #### Option 2: Running on your computer locally
#
# To run the code on your computer locally, you'll need to set up [Python](https://www.python.org), download the notebook and install the required libraries. We recommend using the [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/) distribution of Python. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.
#
# >  **Jupyter Notebooks**: This file is a [Jupyter notebook](https://jupyter.org) - a document made of _cells_. Each cell can contain code written in Python or explanations in plain English. You can execute code cells and view the results, e.g., numbers, messages, graphs, tables, files, etc., instantly within the notebook. Jupyter is a powerful platform for experimentation and analysis. You can use the "Kernel > Restart & Clear Output" menu option to clear all outputs and start again from the top.

# %% [markdown]
# ## Importing Denpendencies

# %%
import pandas as pd
import sqlite3
import numpy as np
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# %%time
data = pd.read_csv("dementia_dataset.csv")

# Display the first few rows of the DataFrame
data.columns
# Out:
# CPU times: total: 62.5 ms
# Wall time: 743 ms
# Index(['Subject ID', 'MRI ID', 'Group', 'Visit', 'MR Delay', 'M/F', 'Hand',
#        'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF'],
#       dtype='object')

# %%
data["Group"].unique()
# Out:
# array(['Nondemented', 'Demented', 'Converted'], dtype=object)

# %%
# Displaying a fraction of the data frame
print(data.shape)
data.sample(frac=.01).head()
# Out:
# (373, 15)
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 211  OAS2_0100  OAS2_0100_MR3  Nondemented      3      1752   F    R   82
# 344  OAS2_0175  OAS2_0175_MR2     Demented      2       700   M    R   72
# 349  OAS2_0177  OAS2_0177_MR1  Nondemented      1         0   M    R   68
# 189  OAS2_0090  OAS2_0090_MR1  Nondemented      1         0   M    R   73
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 211    11  4.0  30.0  0.0  1590  0.760  1.104
# 344    16  4.0  28.0  0.5  1796  0.732  0.977
# 349    14  3.0  26.0  0.0  1444  0.778  1.216
# 189    18  2.0  29.0  0.0  1548  0.773  1.134

# %% [markdown]
# `Connect to a SQLite database`

# %%
# creates database
connection = sqlite3.connect("projectDementia.db")

# %%
# store table in database
data.to_sql('Data',connection, if_exists='replace')
# Out:
# 373

# %% [markdown]
# ### Data Cleaning

# %%
# Retrieving data from the 'Data' table into a pandas DataFrame for manipulation
query = 'SELECT * FROM Data'
data_wrangled = pd.read_sql(query, connection)

data_wrangled.head()
# Out:
#    index Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  \
# 0      0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R
# 1      1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R
# 2      2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R
# 3      3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R
# 4      4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R
#
#    Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4   80    12  NaN  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# *Checking for missing values and handling them*

# %%
missing_values = data_wrangled.isnull().sum()
sns.heatmap(data=data_wrangled.isnull(),cbar=False)
plt.show()
print("Missing values detected.")
print("______________________________________________________________________________________________________")
if missing_values.any():
    print("Handling missing data...")
    # Replace missing SES and MMSE values with their respective means
    data_wrangled['SES'].fillna(data_wrangled['SES'].mean().round(0), inplace=True)
    data_wrangled['MMSE'].fillna(data_wrangled['MMSE'].mean().round(0), inplace=True)
    sns.heatmap(data=data_wrangled.isnull(),cbar=False)
    plt.show()
    print("Missing values handled.")
else:
    print("No missing values found.")
    sns.heatmap(data=data_wrangled.isnull(),cbar=False)
    plt.show()
# Out:
# Missing values detected.
# ______________________________________________________________________________________________________
# Handling missing data...
# C:\Users\hp\AppData\Local\Temp\ipykernel_3804\3719242573.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_wrangled['SES'].fillna(data_wrangled['SES'].mean().round(0), inplace=True)
# ...

# %%
# ensure we got rid of missing data
data_wrangled.isnull().sum()
# Out:
# index         0
# Subject ID    0
# MRI ID        0
# Group         0
# Visit         0
# MR Delay      0
# M/F           0
# Hand          0
# Age           0
# EDUC          0
# SES           0
# MMSE          0
# CDR           0
# eTIV          0
# nWBV          0
# ASF           0
# dtype: int64

# %% [markdown]
# *Encoding Categorical Variables*

# %%
#Gender (M/F) - (0 = Female, 1 = Male)
data_wrangled['M/F'] = data_wrangled['M/F'].replace({'F': 0, 'M': 1})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3804\3122408834.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_wrangled['M/F'] = data_wrangled['M/F'].replace({'F': 0, 'M': 1})

# %% [markdown]
# <!-- Drop the 'Hand' column since all subjects are right-handed -->
# We drop the `Hand` column from the dataset because all subjects in the study are right-handed.

# %%
data_wrangled.drop(columns=['Hand'], inplace=True)

# %%
# Store the processed data back into a new table named 'DataWrangled'
data_wrangled.to_sql('DataWrangled', connection, if_exists='replace', index=False)
# Out:
# 373

# %%
# identify which columns are numerical and categorical
data_wrangled.dtypes
# Out:
# index           int64
# Subject ID     object
# MRI ID         object
# Group          object
# Visit           int64
# MR Delay        int64
# M/F             int64
# Age             int64
# EDUC            int64
# SES           float64
# MMSE          float64
# CDR           float64
# eTIV            int64
# nWBV          float64
# ASF           float64
# dtype: object

# %%
# implement one-hot encoding to M/F, 0 = Female, 1 = Male
data_wrangled['M/F'].replace(to_replace=['F','M'], value=[0,1],inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3804\2337946904.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_wrangled['M/F'].replace(to_replace=['F','M'], value=[0,1],inplace=True)

# %%
data_wrangled.head()
# Out:
#    index Subject ID         MRI ID        Group  Visit  MR Delay  M/F  Age  \
# 0      0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0    1   87
# 1      1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457    1   88
# 2      2  OAS2_0002  OAS2_0002_MR1     Demented      1         0    1   75
# 3      3  OAS2_0002  OAS2_0002_MR2     Demented      2       560    1   76
# 4      4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895    1   80
#
#    EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    14  2.0  30.0  0.0  2004  0.681  0.876
# 2    12  2.0  23.0  0.5  1678  0.736  1.046
# 3    12  2.0  28.0  0.5  1738  0.713  1.010
# 4    12  2.0  22.0  0.5  1698  0.701  1.034

# %%
# identify which columns are numerical and categorical
data_wrangled.dtypes
# Out:
# index           int64
# Subject ID     object
# MRI ID         object
# Group          object
# Visit           int64
# MR Delay        int64
# M/F             int64
# Age             int64
# EDUC            int64
# SES           float64
# MMSE          float64
# CDR           float64
# eTIV            int64
# nWBV          float64
# ASF           float64
# dtype: object

# %%
# make a new table in database for cleaned data
data_wrangled.to_sql('projectCleanedData',connection, if_exists='replace')
# Out:
# 373

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# Retrieving data from the 'Data' table into a pandas DataFrame for manipulation
query = 'SELECT * FROM projectCleanedData'
cleanData = pd.read_sql(query, connection)

cleanData.head()
# Out:
#    level_0  index Subject ID         MRI ID        Group  Visit  MR Delay  \
# 0        0      0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0
# 1        1      1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457
# 2        2      2  OAS2_0002  OAS2_0002_MR1     Demented      1         0
# 3        3      3  OAS2_0002  OAS2_0002_MR2     Demented      2       560
# 4        4      4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895
#
#    M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    1   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    1   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2    1   75    12  2.0  23.0  0.5  1678  0.736  1.046
# 3    1   76    12  2.0  28.0  0.5  1738  0.713  1.010
# 4    1   80    12  2.0  22.0  0.5  1698  0.701  1.034

# %%
cleanData["Group"].unique()
# Out:
# array(['Nondemented', 'Demented', 'Converted'], dtype=object)

# %%
cleanData.describe()
# Out:
#           level_0       index       Visit     MR Delay         M/F  \
# count  373.000000  373.000000  373.000000   373.000000  373.000000
# mean   186.000000  186.000000    1.882038   595.104558    0.428954
# std    107.820066  107.820066    0.922843   635.485118    0.495592
# min      0.000000    0.000000    1.000000     0.000000    0.000000
# 25%     93.000000   93.000000    1.000000     0.000000    0.000000
# 50%    186.000000  186.000000    2.000000   552.000000    0.000000
# 75%    279.000000  279.000000    2.000000   873.000000    1.000000
# max    372.000000  372.000000    5.000000  2639.000000    1.000000
#
#               Age        EDUC         SES        MMSE         CDR  \
# count  373.000000  373.000000  373.000000  373.000000  373.000000
# mean    77.013405   14.597855    2.436997   27.340483    0.290885
# std      7.640957    2.876339    1.109307    3.673415    0.374557
# min     60.000000    6.000000    1.000000    4.000000    0.000000
# ...

# %% [markdown]
# #### Statistical Insights from Dataset
#
# The dataset contains longitudinal data from 373 imaging sessions of 150 subjects aged between 60 and 96 years. Here are key statistical insights:
#
# - **Count**: The dataset includes 373 observations across various features.
# - **Mean Age**: Subjects have a mean age of approximately 77 years.
# - **Education (EDUC)**: The average years of education is about 14.6.
# - **Mini-Mental State Examination (MMSE)**: The mean MMSE score is 27.34, indicating relatively good cognitive function on average.
# - **Clinical Dementia Rating (CDR)**: The average CDR score is 0.29, suggesting predominantly non-demented status across subjects.
# - **Estimated Total Intracranial Volume (eTIV)**: Mean eTIV is 1488.13 mm³, with a range from 1106 mm³ to 2004 mm³.
# - **Gender (M/F)**: The dataset is balanced between genders, with 42.9% male and 57.1% female.
# - **ASF (Atlas Scaling Factor)**: The mean ASF is 1.195, reflecting the scaling factor used in brain image analysis.

# %%
cleanData["Group"].unique()
# Out:
# array(['Nondemented', 'Demented', 'Converted'], dtype=object)

# %% [markdown]
# *Checking for outliers*

# %%
cleanData.plot(kind='box',figsize=(12,10),subplots=True,layout=(5,5))
plt.show()

# %%
# Calculate the distribution of 'Group' column
group_counts = cleanData['Group'].value_counts()

# Plot the pie chart
plt.figure(figsize=(5, 5))
plt.pie(group_counts, labels=group_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Distribution of Groups')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# #### Group Distribution Insight
#
# The dataset includes subjects divided into three groups based on their dementia status:
#
# - **39.1%** of the subjects are **Demented**.
# - **50.9%** of the subjects are **Nondemented**.
# - **9.9%** of the subjects are **Converted**.
#
# This means that about 39% of the subjects have dementia, about 51% do not have dementia, and about 10% transitioned from not having dementia to having dementia.

# %% [markdown]
# ### What could be the cause?

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Age', data=cleanData, palette='viridis')
plt.title('Age Distribution Across All Subjects')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3804\3405028983.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age', data=cleanData, palette='viridis')

# %%
# Count Plots for Each Group
plt.figure(figsize=(12, 6))
sns.countplot(x='Age', hue='Group', data=cleanData, palette='viridis')
plt.title('Age Distribution by Group (Nondemented, Converted, Demented)')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Group')
plt.show()

# %%
# Filter data for Nondemented and Converted groups
nondemented_ages = cleanData[cleanData['Group'] == 'Nondemented']['Age']
converted_ages = cleanData[cleanData['Group'] == 'Converted']['Age']
nondemented_ages = cleanData[cleanData['Group'] == 'Demented']['Age']

# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Group', y='Age', data=cleanData, order=['Nondemented', 'Converted','Demented'])
plt.title('Comparison of Ages between Nondemented and Converted Groups')
plt.xlabel('Group')
plt.ylabel('Age')
plt.show()

# %% [markdown]
#  **Age Range and Median Age Differences:**
#
# The median age of the `Converted group is 81 years`, while the `Nondemented group's is 73 years` and the `Demented group's is 74 years`.
# The age range of those who developed dementia (the `Converted group`) is `74–87 years old`, suggesting that ***conversion typically affects older people***.
#
# ***`As evidenced by the finding that people who converted to dementia tended to be older.`***

# %%
# Plotting the distribution of Age with Group differentiation
plt.figure(figsize=(10, 6))
sns.histplot(data=cleanData, x='Age', bins=range(60, 101, 5), kde=False, hue='Group', multiple='dodge')
plt.title('Age Distribution by Group')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Group', loc='upper right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ***`Age group of 70-80 has the highest count.`***

# %%
plt.figure(figsize=(10, 6))
ax = sns.violinplot(x="M/F", y="Age", hue="Group", split=True, data=cleanData, palette="viridis")
ax.set_title('Age Distribution by Gender and Clinical Dementia Rating (CDR)', fontsize=16)
ax.set_xlabel('Gender (0 = Female, 1 = Male)', fontsize=14)
ax.set_ylabel('Age', fontsize=14)
plt.legend(title='CDR', loc='upper left')
plt.tight_layout()  # Ensuring tight layout for better visibility
plt.show()

# %% [markdown]
# As we can observe from the above plot, in case of Male most number of dementia cases are reported in the age of around 79 years while in case of females dementia is prevalent in 75 years of Age. One more observation suggests that in case of Males dementia starts early even before 60 years of age while in case of females demetia generally after 60 years of age.

# %%
# Define the groups
converted_group = cleanData[cleanData['Group'] == 'Converted']
nondemented_group = cleanData[cleanData['Group'] == 'Nondemented']
demented_group = cleanData[cleanData['Group'] == 'Demented']

# Count the number of male and female subjects in each group
gender_counts_converted = converted_group['M/F'].value_counts()
gender_counts_nondemented = nondemented_group['M/F'].value_counts()
gender_counts_demented = demented_group['M/F'].value_counts()

# %%
# Create a DataFrame for visualization
gender_data = pd.DataFrame({
    'Converted': gender_counts_converted,
    'Nondemented': gender_counts_nondemented,
    'Demented': gender_counts_demented
}).T

# Plot the bar chart
plt.figure(figsize=(12, 6))
gender_data.plot(kind='bar', stacked=False)
plt.title('Gender Distribution in Different Groups')
plt.xlabel('Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Gender', labels=['Female', 'Male'])
plt.show()

# %% [markdown]
# The analysis suggests that the transition from nondemented to demented may involve gender. In particular, compared to men, girls in this sample have a higher propensity to become demented. Males outweigh females in the total demented group, indicating that additional factors may be involved in this disparity.

# %%
# Select only numeric columns for correlation
numeric_data = cleanData.select_dtypes(include=[float, int])

# Handle missing values by filling them with the mean of the column
numeric_data.fillna(numeric_data.mean(), inplace=True)

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Plot the heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
#  As we can see Visit and MR Delay are showing close correlation to 0.92. As we can see from the above plot, there are around 40% of the cases in Normal MMSE status are of dementia cases accroding to CDR scoring.

# %% [markdown]
# **Converting all `"Converted Group"` to Dementia**

# %%
sectionOne = (cleanData['Group']=='Converted') & (cleanData['CDR']>=0.5)
cleanData.loc[sectionOne,'Group']='Demented'
sectionTwo = (cleanData['Group']=='Converted') & (cleanData['CDR']==0.0)
cleanData.loc[sectionTwo,'Group']='Nondemented'
cleanData.loc[cleanData['Group']=='Converted']
# Out:
# Empty DataFrame
# Columns: [level_0, index, Subject ID, MRI ID, Group, Visit, MR Delay, M/F, Age, EDUC, SES, MMSE, CDR, eTIV, nWBV, ASF]
# Index: []

# %%
cleanData['Group'].unique()
# Out:
# array(['Nondemented', 'Demented'], dtype=object)

# %%
# List of key features to plot
features = ['EDUC', 'SES', 'MMSE', 'eTIV', 'nWBV']

# Setting the figure size
plt.figure(figsize=(11, 17))

# Loop through each feature to create a subplot
for i, feature in enumerate(features, 1):
    plt.subplot(3, 2, i)
    sns.violinplot(x="M/F", y=feature, hue="Group", split=True, data=cleanData)
    plt.title(f'Distribution of {feature} by Gender and CDR')
    plt.xlabel('Gender (0 = Female, 1 = Male)')
    plt.ylabel(feature)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
#  ### EDUC
#
#  - As we can observe from the above plot, Mens having education level between 10 and 17 have higher level of dementia cases and mens started to show dymentia symptoms with less education levels starting from 4 years whereas females starts showing dymentia symptoms after 6 years of education level having highest peak at level 13.

# %% [markdown]
# ### SES
#
# - An intriguing pattern can be seen in the above plot: for men, the highest peak is at 1, which corresponds to the highest status, and the lowest peak is at 4, which corresponds to the lowest status. In contrast, for women, the highest peak is at 2, and the lowest status cases are reported between 1 and 5. According to this, women are less likely than males to experience dementia at both extremely high and extremely low socioeconomic class levels.

# %% [markdown]
# ### MMSE (Mini-Mental State Examination score (range is from 0 = worst to 30 = best))
#
# - An intriguing pattern can be seen in the above plot: both men and women, the highest peak is at 28, which corresponds close to the best MMSE score, and for men the lowest peak is at 10. In contrast, for women, the lowest peak is at 12.
#
# > The majority of men and women have strong cognitive function, with MMSE scores of approximately 28. There is a distinction in the lower scores, though: women's scores do not fall below 12, but men's scores typically fall to 10. This implies that compared to women, men may have a greater spectrum of cognitive deterioration.

# %% [markdown]
# ### eTIV
#
# The eTIV of demented female starts from 1000 to 1850 with a pick at level  1500 and for male starts from 1200 to 2100. This implies that males tend to have a broader range of eTIV values, and their peaks are slightly higher compared to females. This difference in eTIV distribution between genders could indicate variations in brain structure and volume related to dementia, suggesting the need for gender-specific approaches in understanding and treating the condition.

# %% [markdown]
# ### nWBV
#
# The nWBV of male and female are different. For male the demented poeple have a nWBV is high between 0.65 and 0.75.

# %% [markdown]
# ### Label Encoding

# %%
# Convert 'Group' column in cleanData
cleanData['Group'] = cleanData['Group'].map({'Demented': 1, 'Nondemented': 0})

# Verify changes
cleanData.head()
# Out:
#    level_0  index Subject ID         MRI ID  Group  Visit  MR Delay  M/F  Age  \
# 0        0      0  OAS2_0001  OAS2_0001_MR1      0      1         0    1   87
# 1        1      1  OAS2_0001  OAS2_0001_MR2      0      2       457    1   88
# 2        2      2  OAS2_0002  OAS2_0002_MR1      1      1         0    1   75
# 3        3      3  OAS2_0002  OAS2_0002_MR2      1      2       560    1   76
# 4        4      4  OAS2_0002  OAS2_0002_MR3      1      3      1895    1   80
#
#    EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    14  2.0  30.0  0.0  2004  0.681  0.876
# 2    12  2.0  23.0  0.5  1678  0.736  1.046
# 3    12  2.0  28.0  0.5  1738  0.713  1.010
# 4    12  2.0  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# ### Seperating data and labels

# %%
# Seperating Data and labels

labels = cleanData.drop(columns = 'Group',axis = 1)
target = cleanData['Group']

# %%
labels.head()
# Out:
#    level_0  index Subject ID         MRI ID  Visit  MR Delay  M/F  Age  EDUC  \
# 0        0      0  OAS2_0001  OAS2_0001_MR1      1         0    1   87    14
# 1        1      1  OAS2_0001  OAS2_0001_MR2      2       457    1   88    14
# 2        2      2  OAS2_0002  OAS2_0002_MR1      1         0    1   75    12
# 3        3      3  OAS2_0002  OAS2_0002_MR2      2       560    1   76    12
# 4        4      4  OAS2_0002  OAS2_0002_MR3      3      1895    1   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  2.0  23.0  0.5  1678  0.736  1.046
# 3  2.0  28.0  0.5  1738  0.713  1.010
# 4  2.0  22.0  0.5  1698  0.701  1.034

# %%
target.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Group, dtype: int64

# %% [markdown]
# Dropping Unnecessary Columns

# %%
labels.drop(['Subject ID', 'MRI ID','level_0','index'], axis=1, inplace=True)

# Verify the DataFrame after dropping the columns
labels.head()
# Out:
#    Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      1         0    1   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1      2       457    1   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2      1         0    1   75    12  2.0  23.0  0.5  1678  0.736  1.046
# 3      2       560    1   76    12  2.0  28.0  0.5  1738  0.713  1.010
# 4      3      1895    1   80    12  2.0  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# # Prediction

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(labels)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(labels)

# %%
standardized_data
# Out:
# array([[-0.95706686, -0.93771494,  1.15379808, ...,  2.83605891,
#         -0.90516867, -2.2657425 ],
#        [ 0.12799678, -0.21761337,  1.15379808, ...,  2.93270307,
#         -1.30964265, -2.31650145],
#        [-0.95706686, -0.93771494,  1.15379808, ...,  1.07940909,
#          0.17342861, -1.08378418],
#        ...,
#        [-0.95706686, -0.93771494, -0.86670278, ..., -0.96148827,
#          1.92614919,  0.98283006],
#        [ 0.12799678,  0.2645553 , -0.86670278, ..., -0.91600866,
#          1.79132453,  0.92481984],
#        [ 1.21306043,  1.59603414, -0.86670278, ..., -0.88189896,
#          1.92614919,  0.88131217]])

# %% [markdown]
# **Splitting data into train test split**

# %%
from sklearn.model_selection import train_test_split

# %%
labels_train,labels_test,target_train,target_test = train_test_split(labels,target,test_size = 0.2,stratify = target,random_state=0)

print(f"Original data size: {data.shape[0]}")
print(f"Training set size: {target_train.shape[0]}")
print(f"Testing set size: {labels_test.shape[0]}")
# Out:
# Original data size: 373
# Training set size: 298
# Testing set size: 75

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score


classifier = svm.SVC(kernel='linear')

classifier.fit(labels_train,target_train)
# Out:
# SVC(kernel='linear')

# %%
# Finding accuracy score on the training data
labels_train_prediction = classifier.predict(labels_train)
training_data_accuracy = accuracy_score(labels_train_prediction,target_train)

# %%
print("The acuracy score of the training data: ", training_data_accuracy)
# Out:
# The acuracy score of the training data:  0.9932885906040269

# %% [markdown]
# ## Predicting System
#
# This is going to predict based on 0 and 1
#
# - 1 > Demented
# - 0 > Nondemented

# %%
labels.columns
# Out:
# Index(['Visit', 'MR Delay', 'M/F', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV',
#        'nWBV', 'ASF'],
#       dtype='object')

# %%
data.sample(3)
# Out:
#     Subject ID         MRI ID      Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 173  OAS2_0079  OAS2_0079_MR3   Demented      3      1435   F    R   73    12
# 36   OAS2_0020  OAS2_0020_MR1  Converted      1         0   M    R   80    20
# 221  OAS2_0104  OAS2_0104_MR1   Demented      1         0   M    R   70    16
#
#      SES  MMSE  CDR  eTIV   nWBV    ASF
# 173  4.0  16.0  1.0  1478  0.696  1.188
# 36   1.0  29.0  0.0  1587  0.693  1.106
# 221  1.0  25.0  0.5  1568  0.696  1.119

# %%
# Inputs are : ['Visit','MR Delay', 'M/F', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV','nWBV', 'ASF']

input_data = (2,802,0,65,15,2.0,28.0,0.0,1542,0.792,1.138)

# changin the input data to a numpy array

input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for only one instance

input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

# standardizing the input data
std_data =  scaler.transform(input_data_reshape)

print(std_data)
# Out:
# [[ 0.12799678  0.32600817 -0.86670278 -1.57434999  0.1399991  -0.3944662
#    0.17977913 -0.77765291  0.30625577  1.6834648  -0.4166666 ]]
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = classifier.predict(std_data)

print('The prediction is :', prediction)

if prediction[0] == 0:
    print("Nondemented")
else:
    print("Demented")
# Out:
# The prediction is : [0]
# Nondemented
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# MODEL DEPLOYMENT

# %%
import pickle

filename = "trained_model.pkl"

pickle.dump(classifier,open(filename,"wb"))

# loading the saved model

loaded_model = pickle.load(open("trained_model.pkl","rb"))
input_data = (1,0,0,96,17,1.0,26.0,1.0,1465,0.683,1.198)

# changin the input data to a numpy array

input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for only one instance

input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

prediction = loaded_model.predict(input_data_reshape)

print('The prediction is :', prediction)

if prediction[0] == 0:
    print("Non-Diabetic")
else:
    (print("Diabetic"))
# Out:
# The prediction is : [1]
# Diabetic
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
